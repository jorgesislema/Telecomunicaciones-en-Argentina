# %%
import pandas as pd
import numpy  as np
import os

# %%
# Cargamos la ruta del archivo Excel
excel_file = r'C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .xlsx/Television.xlsx'

# Leemos todas las hojas del archivo Excel
hojas = pd.read_excel(excel_file, sheet_name=None)  # Cambiado "read_exel" a "read_excel"

# Convertimos cada hoja a un archivo CSV
for nombre_hoja, datos_hoja in hojas.items():  # Cambiado "itens" a "items"
    nombre_csv = f'C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/Television/{nombre_hoja}.csv'
    datos_hoja.to_csv(nombre_csv, index=False)  # Cambiado "to.scv" a "to_csv"
    print(f"La hoja de nombre '{nombre_hoja}' ha sido convertida a {nombre_csv}")
# Out:
# La hoja de nombre 'Accesos_prov_TV' ha sido convertida a C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/Television/Accesos_prov_TV.csv
# La hoja de nombre 'Accesos_totales_TV' ha sido convertida a C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/Television/Accesos_totales_TV.csv
# La hoja de nombre 'Ingresos_TV' ha sido convertida a C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/Television/Ingresos_TV.csv
# La hoja de nombre 'Penetracion_prov_TV' ha sido convertida a C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/Television/Penetracion_prov_TV.csv
# La hoja de nombre 'Penetracion_totales_TV' ha sido convertida a C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/Television/Penetracion_totales_TV.csv

# %% [markdown]
# ETE Accesos_prov_TV.csv

# %% [markdown]
# Cargamos el data set Accesos_prov_TV.csv y realizamos una exploración para ver datos faltantes ,su estructura y visualizar las primeras líneas

# %%
# Cargamos el archivo 
archivo= r'C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/Television/Accesos_prov_TV.csv'
print(f"Análisis para el archivo: {archivo}") 
df = pd.read_csv(archivo)

 # Realizamos el analisis  de el archivo
print(df.head())         
print(df.info())        
print(df.describe())     
print(f"Dimensiones del dataframe: {df.shape}")

# Análisamos el porsentaje de valores nulos valores nulos
print("Valores nulos por columna")
print(df.isnull().sum())

# Contamos el valores faltantes
missing_values = df.isnull().mean() * 100
print("Porcentaje de valores faltantes por columna:\n", missing_values)

# Contamos el número de filas duplicadas
num_duplicates = df.duplicated(keep=False).sum()
print("Número total de filas duplicadas:", num_duplicates)
print("\n" + "="*50 + "\n")  # Separador para cada archivo
# Out:
# Análisis para el archivo: C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/Television/Accesos_prov_TV.csv
#     Año  Trimestre        Provincia  Accesos TV por suscripción (Vrf)
# 0  2024          2     Buenos Aires                           2873482
# 1  2024          2  Capital Federal                            693686
# 2  2024          2        Catamarca                             54865
# 3  2024          2            Chaco                            115238
# 4  2024          2           Chubut                             78471
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1008 entries, 0 to 1007
# Data columns (total 4 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Año                               1008 non-null   int64
#  1   Trimestre                         1008 non-null   int64
#  2   Provincia                         1008 non-null   object
#  3   Accesos TV por suscripción (Vrf)  1008 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 31.6+ KB
# None
#                Año    Trimestre  Accesos TV por suscripción (Vrf)
# count  1008.000000  1008.000000                      1.008000e+03
# mean   2018.761905     2.452381                      2.936286e+05
# std       3.039439     1.117574                      5.735723e+05
# min    2014.000000     1.000000                      1.686900e+04
# 25%    2016.000000     1.000000                      5.489825e+04
# 50%    2019.000000     2.000000                      9.898000e+04
# 75%    2021.000000     3.000000                      1.547750e+05
# max    2024.000000     4.000000                      3.129739e+06
# Dimensiones del dataframe: (1008, 4)
# Valores nulos por columna
# Año                                 0
# Trimestre                           0
# Provincia                           0
# Accesos TV por suscripción (Vrf)    0
# dtype: int64
# Porcentaje de valores faltantes por columna:
#  Año                                 0.0
# Trimestre                           0.0
# Provincia                           0.0
# Accesos TV por suscripción (Vrf)    0.0
# dtype: float64
# Número total de filas duplicadas: 0
#
# ==================================================

# %% [markdown]
# Cambiamos el formato de fecha para que sea un formato más compatible con Python uniendo la columna fecha con la columna trimestre y se crea la columna Id_Provincia

# %%
# Cargamos el archivo CSV
archivo = r'C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/Television/Accesos_prov_TV.csv'
df = pd.read_csv(archivo)

# Mapeamos los trimestres al último día de cada trimestre
trimestre_map = {1: "03-31", 2: "06-30", 3: "09-30", 4: "12-31"}

# Convertimos 'Año' a cadena y mapear 'Trimestre' al último día del trimestre
if 'Año' in df.columns and 'Trimestre' in df.columns:
    df['Año'] = df['Año'].astype(str)
    df['Trimestre'] = df['Trimestre'].map(trimestre_map)

    # Creamos la columna 'Fecha' combinando 'Año' y 'Trimestre'
    df['Fecha'] = pd.to_datetime(df['Año'] + "-" + df['Trimestre'])

    # Borramos  las columnas 'Año' y 'Trimestre'
    df.drop(columns=['Año', 'Trimestre'], inplace=True)

    # Reordenamos las columnas 
    cols = ['Fecha'] + [col for col in df.columns if col != 'Fecha']
    df = df[cols]
else:
    print("Error: Las columnas 'Año' y 'Trimestre' no se encontraron en los datos.")


# Identificamos todas las provincias en el dataset
provincias = df['Provincia'].unique()
print("Provincias en Argentina:", provincias)
print("Número total de provincias:", len(provincias))

# Creamos un diccionario de ID únicos para cada provincia, comenzando desde 1
provincia_id_map = {provincia: idx + 1 for idx, provincia in enumerate(provincias)}

# Creamos la columna Id_Provincia usando el diccionario
df['Id_Provincia'] = df['Provincia'].map(provincia_id_map)

# Ordenamos el dataset según el orden de columnas
column_order = ['Id_Provincia','Provincia', 'Fecha','Accesos TV por suscripción (Vrf)']
df = df[column_order]

# Guardamos el DataFrame final en un archivo CSV
output_path = r'C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/Television/Accesos_prov_TV.csv'
df.to_csv(output_path, index=False)

print(df.head())
# Out:
# Provincias en Argentina: ['Buenos Aires' 'Capital Federal' 'Catamarca' 'Chaco' 'Chubut' 'Córdoba'
#  'Corrientes' 'Entre Ríos' 'Formosa' 'Jujuy' 'La Pampa' 'La Rioja'
#  'Mendoza' 'Misiones' 'Neuquén' 'Río Negro' 'Salta' 'San Juan' 'San Luis'
#  'Santa Cruz' 'Santa Fe' 'Santiago Del Estero' 'Tierra Del Fuego'
#  'Tucumán' 'Santiago del Estero' 'Tierra del Fuego']
# Número total de provincias: 26
#    Id_Provincia        Provincia      Fecha  Accesos TV por suscripción (Vrf)
# 0             1     Buenos Aires 2024-06-30                           2873482
# 1             2  Capital Federal 2024-06-30                            693686
# 2             3        Catamarca 2024-06-30                             54865
# 3             4            Chaco 2024-06-30                            115238
# 4             5           Chubut 2024-06-30                             78471

# %% [markdown]
# ETL Accesos_totales_TV.csv

# %% [markdown]
# Cargamos el data set Accesos_totales_TV.csv y realizamos una exploración para ver datos faltantes ,su estructura y visualizar las primeras líneas

# %%
# Cargamos el archivo 
archivo= r'C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/Television/Accesos_totales_TV.csv'
print(f"Análisis para el archivo: {archivo}") 
df = pd.read_csv(archivo)

 # Realizamos el analisis  de el archivo
print(df.head())         
print(df.info())        
print(df.describe())     
print(f"Dimensiones del dataframe: {df.shape}")

# Análisamos el porsentaje de valores nulos valores nulos
print("Valores nulos por columna")
print(df.isnull().sum())

# Contamos el valores faltantes
missing_values = df.isnull().mean() * 100
print("Porcentaje de valores faltantes por columna:\n", missing_values)

# Contamos el número de filas duplicadas
num_duplicates = df.duplicated(keep=False).sum()
print("Número total de filas duplicadas:", num_duplicates)
print("\n" + "="*50 + "\n")  # Separador para cada archivo
# Out:
# Análisis para el archivo: C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/Television/Accesos_totales_TV.csv
#     Año  Trimestre  Accesos TV por suscripción  Accesos TV satelital  \
# 0  2024          2                     7454428               1367489
# 1  2024          1                     7601499               1445205
# 2  2023          4                     7650809               1508789
# 3  2023          3                     7743735               1683205
# 4  2023          2                     8076400               1735655
#
#          Periodo
# 0  Abr-Junio 2024
# 1    Ene-Mar 2024
# 2    Oct-Dic 2023
# 3   Jul-Sept 2022
# 4    Abr-Jun 2023
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 5 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Año                         41 non-null     int64
#  1   Trimestre                   41 non-null     int64
#  2   Accesos TV por suscripción  41 non-null     int64
#  3   Accesos TV satelital        41 non-null     int64
#  4    Periodo                    41 non-null     object
# dtypes: int64(4), object(1)
# memory usage: 1.7+ KB
# None
#                Año  Trimestre  Accesos TV por suscripción  \
# count    41.000000  41.000000                4.100000e+01
# mean   2018.878049   2.487805                7.086233e+06
# std       3.018237   1.120758                4.832267e+05
# min    2014.000000   1.000000                6.409504e+06
# 25%    2016.000000   2.000000                6.553801e+06
# 50%    2019.000000   2.000000                7.048709e+06
# 75%    2021.000000   3.000000                7.564827e+06
# max    2024.000000   4.000000                8.076400e+06
#
#        Accesos TV satelital
# count          4.100000e+01
# mean           2.297208e+06
# std            3.572491e+05
# min            1.367489e+06
# 25%            2.064699e+06
# 50%            2.460177e+06
# 75%            2.537610e+06
# max            2.662031e+06
# Dimensiones del dataframe: (41, 5)
# Valores nulos por columna
# Año                           0
# Trimestre                     0
# Accesos TV por suscripción    0
# Accesos TV satelital          0
#  Periodo                      0
# dtype: int64
# Porcentaje de valores faltantes por columna:
#  Año                           0.0
# Trimestre                     0.0
# Accesos TV por suscripción    0.0
# Accesos TV satelital          0.0
#  Periodo                      0.0
# dtype: float64
# Número total de filas duplicadas: 0
#
# ==================================================

# %% [markdown]
# Cambiamos el formato de fecha para que sea un formato más compatible con Python uniendo la columna fecha con la columna trimestre y se elimina la columna Periodo

# %%
# Cargamos el archivo CSV
archivo = r'C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/Television/Accesos_totales_TV.csv'
df = pd.read_csv(archivo)

# Mapeamos los trimestres al último día de cada trimestre
trimestre_map = {1: "03-31", 2: "06-30", 3: "09-30", 4: "12-31"}

# Convertimos 'Año' a cadena y mapear 'Trimestre' al último día del trimestre
if 'Año' in df.columns and 'Trimestre' in df.columns:
    df['Año'] = df['Año'].astype(str)
    df['Trimestre'] = df['Trimestre'].map(trimestre_map)

    # Creamos la columna 'Fecha' combinando 'Año' y 'Trimestre'
    df['Fecha'] = pd.to_datetime(df['Año'] + "-" + df['Trimestre'])

    # Borramos  las columnas 'Año' y 'Trimestre'
    df.drop(columns=['Año', 'Trimestre'], inplace=True)

    # Reordenamos las columnas 
    cols = ['Fecha'] + [col for col in df.columns if col != 'Fecha']
    df = df[cols]
else:
    print("Error: Las columnas 'Año' y 'Trimestre' no se encontraron en los datos.")
        # Eliminamos la columna 'Periodo'
df.columns = df.columns.str.strip()
if 'Periodo' in df.columns:
    df.drop(columns=['Periodo'], inplace=True)

    # Guardamos el DataFrame final en un archivo CSV
output_path = r'C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/Television/Accesos_totales_TV1.csv'
df.to_csv(output_path, index=False)

print(df.head())
# Out:
#        Fecha  Accesos TV por suscripción  Accesos TV satelital
# 0 2024-06-30                     7454428               1367489
# 1 2024-03-31                     7601499               1445205
# 2 2023-12-31                     7650809               1508789
# 3 2023-09-30                     7743735               1683205
# 4 2023-06-30                     8076400               1735655

# %% [markdown]
# ETL Ingresos_TV.csv

# %% [markdown]
# Cargamos el data set Ingresos_TV.csv y realizamos una exploración para ver datos faltantes ,su estructura y visualizar las primeras líneas

# %%
# Cargamos el archivo 
archivo= r'C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/Television/Ingresos_TV.csv'
print(f"Análisis para el archivo: {archivo}") 

 # Realizamos el analisis  de el archivo
print(df.head())         
print(df.info())        
print(df.describe())     
print(f"Dimensiones del dataframe: {df.shape}")

# Análisamos el porsentaje de valores nulos valores nulos
print("Valores nulos por columna")
print(df.isnull().sum())

# Contamos el valores faltantes
missing_values = df.isnull().mean() * 100
print("Porcentaje de valores faltantes por columna:\n", missing_values)

# Contamos el número de filas duplicadas
num_duplicates = df.duplicated(keep=False).sum()
print("Número total de filas duplicadas:", num_duplicates)
print("\n" + "="*50 + "\n")  # Separador para cada archivo
# Out:
# Análisis para el archivo: C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/Television/Ingresos_TV.csv
#     Año  Trimestre  Ingresos TV por suscripción  (miles de $)  \
# 0  2024          2                               2.662339e+08
# 1  2024          1                               1.910639e+08
# 2  2023          4                               1.335822e+08
# 3  2023          3                               1.037380e+08
# 4  2023          2                               8.701537e+07
#
#    Ingresos TV satelital (miles de $)
# 0                        1.248149e+08
# 1                        9.427053e+07
# 2                        6.474882e+07
# 3                        5.117948e+07
# 4                        3.862515e+07
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 4 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Año                                        42 non-null     int64
#  1   Trimestre                                  42 non-null     int64
#  2   Ingresos TV por suscripción  (miles de $)  42 non-null     float64
#  3   Ingresos TV satelital (miles de $)         42 non-null     float64
# dtypes: float64(2), int64(2)
# memory usage: 1.4 KB
# None
#                Año  Trimestre  Ingresos TV por suscripción  (miles de $)  \
# count    42.000000  42.000000                               4.200000e+01
# mean   2018.761905   2.452381                               3.687273e+07
# std       3.074756   1.130560                               5.258216e+07
# min    2014.000000   1.000000                               3.599484e+06
# 25%    2016.000000   1.250000                               8.349606e+06
# 50%    2019.000000   2.000000                               1.793585e+07
# 75%    2021.000000   3.000000                               3.780455e+07
# max    2024.000000   4.000000                               2.662339e+08
#
#        Ingresos TV satelital (miles de $)
# count                        4.200000e+01
# mean                         1.836451e+07
# std                          2.485055e+07
# min                          2.001221e+06
# 25%                          4.744078e+06
# 50%                          9.377049e+06
# 75%                          1.803925e+07
# max                          1.248149e+08
# Dimensiones del dataframe: (42, 4)
# Valores nulos por columna
# Año                                          0
# Trimestre                                    0
# Ingresos TV por suscripción  (miles de $)    0
# Ingresos TV satelital (miles de $)           0
# dtype: int64
# Porcentaje de valores faltantes por columna:
#  Año                                          0.0
# Trimestre                                    0.0
# Ingresos TV por suscripción  (miles de $)    0.0
# Ingresos TV satelital (miles de $)           0.0
# dtype: float64
# Número total de filas duplicadas: 0
#
# ==================================================

# %% [markdown]
# Cambiamos el formato de fecha para que sea un formato más compatible con Python uniendo la columna fecha con la columna trimestre.

# %%
# Cargamos el archivo CSV
archivo = r'C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/Television/Ingresos_TV.csv'
df = pd.read_csv(archivo)

# Mapeamos los trimestres al último día de cada trimestre
trimestre_map = {1: "03-31", 2: "06-30", 3: "09-30", 4: "12-31"}

# Convertimos 'Año' a cadena y mapear 'Trimestre' al último día del trimestre
if 'Año' in df.columns and 'Trimestre' in df.columns:
    df['Año'] = df['Año'].astype(str)
    df['Trimestre'] = df['Trimestre'].map(trimestre_map)

    # Creamos la columna 'Fecha' combinando 'Año' y 'Trimestre'
    df['Fecha'] = pd.to_datetime(df['Año'] + "-" + df['Trimestre'])

    # Borramos  las columnas 'Año' y 'Trimestre'
    df.drop(columns=['Año', 'Trimestre'], inplace=True)

    # Reordenamos las columnas 
    cols = ['Fecha'] + [col for col in df.columns if col != 'Fecha']
    df = df[cols]
else:
    print("Error: Las columnas 'Año' y 'Trimestre' no se encontraron en los datos.")

output_path = r'C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/Television/Ingresos_TV.csv'
df.to_csv(output_path, index=False)

print(df.head())
# Out:
#        Fecha  Ingresos TV por suscripción  (miles de $)  \
# 0 2024-06-30                               2.662339e+08
# 1 2024-03-31                               1.910639e+08
# 2 2023-12-31                               1.335822e+08
# 3 2023-09-30                               1.037380e+08
# 4 2023-06-30                               8.701537e+07
#
#    Ingresos TV satelital (miles de $)
# 0                        1.248149e+08
# 1                        9.427053e+07
# 2                        6.474882e+07
# 3                        5.117948e+07
# 4                        3.862515e+07

# %% [markdown]
# ETL Penetracion_prov_TV.csv

# %% [markdown]
# Cargamos el data set Penetracion_prov_TV.csv y realizamos una exploración para ver datos faltantes ,su estructura y visualizar las primeras líneas

# %%
# Cargamos el archivo 
archivo= r'C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/Television/Penetracion_prov_TV.csv'
print(f"Análisis para el archivo: {archivo}") 
df = pd.read_csv(archivo)

 # Realizamos el analisis  de el archivo
print(df.head())         
print(df.info())        
print(df.describe())     
print(f"Dimensiones del dataframe: {df.shape}")

# Análisamos el porsentaje de valores nulos valores nulos
print("Valores nulos por columna")
print(df.isnull().sum())

# Contamos el valores faltantes
missing_values = df.isnull().mean() * 100
print("Porcentaje de valores faltantes por columna:\n", missing_values)

# Contamos el número de filas duplicadas
num_duplicates = df.duplicated(keep=False).sum()
print("Número total de filas duplicadas:", num_duplicates)
print("\n" + "="*50 + "\n")  # Separador para cada archivo
# Out:
# Análisis para el archivo: C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/Television/Penetracion_prov_TV.csv
#     Año  Trimestre        Provincia  \
# 0  2024          2     Buenos Aires
# 1  2024          2  Capital Federal
# 2  2024          2        Catamarca
# 3  2024          2            Chaco
# 4  2024          2           Chubut
#
#    Accesos TV por suscripción por cada 100 hab  \
# 0                                        15.80
# 1                                        22.48
# 2                                        12.79
# 3                                         9.23
# 4                                        11.92
#
#    Accesos TV por suscripción por cada 100 hogares
# 0                                            45.98
# 1                                            55.15
# 2                                            50.29
# 3                                            34.52
# 4                                            38.88
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Año                                              1000 non-null   int64
#  1   Trimestre                                        1000 non-null   int64
#  2   Provincia                                        1000 non-null   object
#  3   Accesos TV por suscripción por cada 100 hab      1000 non-null   float64
#  4   Accesos TV por suscripción por cada 100 hogares  1000 non-null   float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 39.2+ KB
# None
#                Año    Trimestre  Accesos TV por suscripción por cada 100 hab  \
# count  1000.000000  1000.000000                                  1000.000000
# mean   2018.800000     2.464000                                    13.533702
# std       3.021445     1.114426                                     6.415391
# min    2014.000000     1.000000                                     3.802404
# 25%    2016.000000     1.000000                                     8.892282
# 50%    2019.000000     2.000000                                    11.846055
# 75%    2021.000000     3.000000                                    16.717500
# max    2024.000000     4.000000                                    31.360000
#
#        Accesos TV por suscripción por cada 100 hogares
# count                                      1000.000000
# mean                                         46.277222
# std                                          18.821470
# min                                          14.927184
# 25%                                          32.490000
# 50%                                          41.241411
# 75%                                          57.511632
# max                                         102.430000
# Dimensiones del dataframe: (1000, 5)
# Valores nulos por columna
# Año                                                0
# Trimestre                                          0
# Provincia                                          0
# Accesos TV por suscripción por cada 100 hab        0
# Accesos TV por suscripción por cada 100 hogares    0
# dtype: int64
# Porcentaje de valores faltantes por columna:
#  Año                                                0.0
# Trimestre                                          0.0
# Provincia                                          0.0
# Accesos TV por suscripción por cada 100 hab        0.0
# Accesos TV por suscripción por cada 100 hogares    0.0
# dtype: float64
# Número total de filas duplicadas: 0
#
# ==================================================

# %% [markdown]
# Cambiamos el formato de fecha para que sea un formato más compatible con Python uniendo la columna fecha con la columna trimestre y se crea la columna Id_Provincia

# %%
# Cargamos el archivo CSV
archivo = r'C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/Television/Penetracion_prov_TV.csv'
df = pd.read_csv(archivo)

# Mapeamos los trimestres al último día de cada trimestre
trimestre_map = {1: "03-31", 2: "06-30", 3: "09-30", 4: "12-31"}

# Convertimos 'Año' a cadena y mapear 'Trimestre' al último día del trimestre
if 'Año' in df.columns and 'Trimestre' in df.columns:
    df['Año'] = df['Año'].astype(str)
    df['Trimestre'] = df['Trimestre'].map(trimestre_map)

    # Creamos la columna 'Fecha' combinando 'Año' y 'Trimestre'
    df['Fecha'] = pd.to_datetime(df['Año'] + "-" + df['Trimestre'])

    # Borramos  las columnas 'Año' y 'Trimestre'
    df.drop(columns=['Año', 'Trimestre'], inplace=True)

    # Reordenamos las columnas 
    cols = ['Fecha'] + [col for col in df.columns if col != 'Fecha']
    df = df[cols]
else:
    print("Error: Las columnas 'Año' y 'Trimestre' no se encontraron en los datos.")


# Identificamos todas las provincias en el dataset
provincias = df['Provincia'].unique()
print("Provincias en Argentina:", provincias)
print("Número total de provincias:", len(provincias))

# Creamos un diccionario de ID únicos para cada provincia, comenzando desde 1
provincia_id_map = {provincia: idx + 1 for idx, provincia in enumerate(provincias)}

# Creamos la columna Id_Provincia usando el diccionario
df['Id_Provincia'] = df['Provincia'].map(provincia_id_map)

# Ordenamos el dataset según el orden de columnas
column_order = ['Id_Provincia','Provincia', 'Fecha','Accesos TV por suscripción por cada 100 hab','Accesos TV por suscripción por cada 100 hogares']
df = df[column_order]

# Guardamos el DataFrame final en un archivo CSV
output_path = r'C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/Television/Penetracion_prov_TV1.csv'
df.to_csv(output_path, index=False)

print(df.head())
# Out:
# Provincias en Argentina: ['Buenos Aires' 'Capital Federal' 'Catamarca' 'Chaco' 'Chubut' 'Córdoba'
#  'Corrientes' 'Entre Ríos' 'Formosa' 'Jujuy' 'La Pampa' 'La Rioja'
#  'Mendoza' 'Misiones' 'Neuquén' 'Río Negro' 'Salta' 'San Juan' 'San Luis'
#  'Santa Cruz' 'Santa Fe' 'Santiago Del Estero' 'Tierra Del Fuego'
#  'Tucumán' 'Santiago del Estero' 'Tierra del Fuego']
# Número total de provincias: 26
#    Id_Provincia        Provincia      Fecha  \
# 0             1     Buenos Aires 2024-06-30
# 1             2  Capital Federal 2024-06-30
# 2             3        Catamarca 2024-06-30
# 3             4            Chaco 2024-06-30
# 4             5           Chubut 2024-06-30
#
#    Accesos TV por suscripción por cada 100 hab  \
# 0                                        15.80
# 1                                        22.48
# 2                                        12.79
# 3                                         9.23
# 4                                        11.92
#
#    Accesos TV por suscripción por cada 100 hogares
# 0                                            45.98
# 1                                            55.15
# 2                                            50.29
# 3                                            34.52
# 4                                            38.88

# %% [markdown]
# ETL Penetracion_totales_TV.csv

# %% [markdown]
# Cargamos el data set Penetracion_totales_TV.csv y realizamos una exploración para ver datos faltantes ,su estructura y visualizar las primeras líneas

# %%
# Cargamos el archivo 
archivo= r'C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/Television/Penetracion_totales_TV.csv'
print(f"Análisis para el archivo: {archivo}") 

df = pd.read_csv(archivo)

 # Realizamos el analisis  de el archivo
print(df.head())         
print(df.info())        
print(df.describe())     
print(f"Dimensiones del dataframe: {df.shape}")

# Análisamos el porsentaje de valores nulos valores nulos
print("Valores nulos por columna")
print(df.isnull().sum())

# Contamos el valores faltantes
missing_values = df.isnull().mean() * 100
print("Porcentaje de valores faltantes por columna:\n", missing_values)

# Contamos el número de filas duplicadas
num_duplicates = df.duplicated(keep=False).sum()
print("Número total de filas duplicadas:", num_duplicates)
print("\n" + "="*50 + "\n")  # Separador para cada archivo
# Out:
# Análisis para el archivo: C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/Television/Penetracion_totales_TV.csv
#     Año  Trimestre  Accesos TV por suscripción por cada 100 hab  \
# 0  2024          2                                        15.85
# 1  2024          1                                        16.20
# 2  2023          4                                        16.34
# 3  2023          3                                        16.57
# 4  2023          2                                        17.32
#
#    Accesos TV satelital por cada 100 hab  \
# 0                                   2.91
# 1                                   3.08
# 2                                   3.22
# 3                                   3.60
# 4                                   3.72
#
#    Accesos TV por suscripción por cada 100 hogares  \
# 0                                            50.40
# 1                                            51.55
# 2                                            52.05
# 3                                            52.84
# 4                                            55.29
#
#    Accesos TV satelital por cada 100 hogares
# 0                                       9.24
# 1                                       9.80
# 2                                      10.26
# 3                                      11.49
# 4                                      11.88
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 6 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Año                                              42 non-null     int64
#  1   Trimestre                                        42 non-null     int64
#  2   Accesos TV por suscripción por cada 100 hab      42 non-null     float64
#  3   Accesos TV satelital por cada 100 hab            42 non-null     float64
#  4   Accesos TV por suscripción por cada 100 hogares  42 non-null     float64
#  5   Accesos TV satelital por cada 100 hogares        42 non-null     float64
# dtypes: float64(4), int64(2)
# memory usage: 2.1 KB
# None
#                Año  Trimestre  Accesos TV por suscripción por cada 100 hab  \
# count    42.000000  42.000000                                    42.000000
# mean   2018.761905   2.452381                                    15.704536
# std       3.074756   1.130560                                     0.784275
# min    2014.000000   1.000000                                    12.736339
# 25%    2016.000000   1.250000                                    15.095918
# 50%    2019.000000   2.000000                                    15.750976
# 75%    2021.000000   3.000000                                    16.192545
# max    2024.000000   4.000000                                    17.320000
#
#        Accesos TV satelital por cada 100 hab  \
# count                              42.000000
# mean                                5.153407
# std                                 0.900544
# min                                 2.910000
# 25%                                 4.522717
# 50%                                 5.500274
# 75%                                 5.790997
# max                                 6.106925
#
#        Accesos TV por suscripción por cada 100 hogares  \
# count                                        42.000000
# mean                                         51.123760
# std                                           1.848002
# min                                          42.721487
# 25%                                          50.351827
# 50%                                          50.842492
# 75%                                          52.024140
# max                                          55.290000
#
#        Accesos TV satelital por cada 100 hogares
# count                                  42.000000
# mean                                   16.812122
# std                                     3.152232
# min                                     9.240000
# 25%                                    14.489688
# 50%                                    17.791961
# 75%                                    19.089578
# max                                    20.493660
# Dimensiones del dataframe: (42, 6)
# Valores nulos por columna
# Año                                                0
# Trimestre                                          0
# Accesos TV por suscripción por cada 100 hab        0
# Accesos TV satelital por cada 100 hab              0
# Accesos TV por suscripción por cada 100 hogares    0
# Accesos TV satelital por cada 100 hogares          0
# dtype: int64
# Porcentaje de valores faltantes por columna:
#  Año                                                0.0
# Trimestre                                          0.0
# Accesos TV por suscripción por cada 100 hab        0.0
# Accesos TV satelital por cada 100 hab              0.0
# Accesos TV por suscripción por cada 100 hogares    0.0
# Accesos TV satelital por cada 100 hogares          0.0
# dtype: float64
# Número total de filas duplicadas: 0
#
# ==================================================

# %% [markdown]
# Cambiamos el formato de fecha para que sea un formato más compatible con Python uniendo la columna fecha con la columna trimestre.

# %%
# Cargamos el archivo CSV
archivo = r'C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/Television/Penetracion_totales_TV.csv'
df = pd.read_csv(archivo)

# Mapeamos los trimestres al último día de cada trimestre
trimestre_map = {1: "03-31", 2: "06-30", 3: "09-30", 4: "12-31"}

# Convertimos 'Año' a cadena y mapear 'Trimestre' al último día del trimestre
if 'Año' in df.columns and 'Trimestre' in df.columns:
    df['Año'] = df['Año'].astype(str)
    df['Trimestre'] = df['Trimestre'].map(trimestre_map)

    # Creamos la columna 'Fecha' combinando 'Año' y 'Trimestre'
    df['Fecha'] = pd.to_datetime(df['Año'] + "-" + df['Trimestre'])

    # Borramos  las columnas 'Año' y 'Trimestre'
    df.drop(columns=['Año', 'Trimestre'], inplace=True)

    # Reordenamos las columnas 
    cols = ['Fecha'] + [col for col in df.columns if col != 'Fecha']
    df = df[cols]
else:
    print("Error: Las columnas 'Año' y 'Trimestre' no se encontraron en los datos.")


# Guardamos el DataFrame final en un archivo CSV
output_path = r'C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/Television/Penetracion_totales_TV.csv'
df.to_csv(output_path, index=False)

print(df.head())
# Out:
#        Fecha  Accesos TV por suscripción por cada 100 hab  \
# 0 2024-06-30                                        15.85
# 1 2024-03-31                                        16.20
# 2 2023-12-31                                        16.34
# 3 2023-09-30                                        16.57
# 4 2023-06-30                                        17.32
#
#    Accesos TV satelital por cada 100 hab  \
# 0                                   2.91
# 1                                   3.08
# 2                                   3.22
# 3                                   3.60
# 4                                   3.72
#
#    Accesos TV por suscripción por cada 100 hogares  \
# 0                                            50.40
# 1                                            51.55
# 2                                            52.05
# 3                                            52.84
# 4                                            55.29
#
#    Accesos TV satelital por cada 100 hogares
# 0                                       9.24
# 1                                       9.80
# 2                                      10.26
# 3                                      11.49
# 4                                      11.88
