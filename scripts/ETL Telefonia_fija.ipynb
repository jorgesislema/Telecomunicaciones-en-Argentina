# %% [markdown]
# Cargamos el data set telefonia_fija.xlsx para extraer la  hoja que lo conforman y la trasformamos a formato .csv y las guardamos en la carpeta telefonia_fija

# %%
import pandas as pd
import numpy as pn

# %%
# Cargamos la ruta del data set telefonia_fija
excel_file = r'C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .xlsx/telefonia_fija.xlsx'

# Leemos todas las hojas del archivo Excel
hojas = pd.read_excel(excel_file, sheet_name=None)

# Convertir cada hoja a un archivo CSV
for nombre_hoja, datos_hoja in hojas.items():
    nombre_csv = f'C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/telefonia_fija/{nombre_hoja}.csv'
    datos_hoja.to_csv(nombre_csv, index=False)
    print(f"La hoja de nombre '{nombre_hoja}' a sido convertida a {nombre_csv}")
# Out:
# La hoja de nombre 'Fija_prov_tipo' a sido convertida a C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/telefonia_fija/Fija_prov_tipo.csv
# La hoja de nombre 'Fija_accesos_tot' a sido convertida a C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/telefonia_fija/Fija_accesos_tot.csv
# La hoja de nombre 'Fija_penetracion_prov' a sido convertida a C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/telefonia_fija/Fija_penetracion_prov.csv
# La hoja de nombre 'Fija_penetracion_tot' a sido convertida a C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/telefonia_fija/Fija_penetracion_tot.csv
# La hoja de nombre 'Fija_ingresos' a sido convertida a C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/telefonia_fija/Fija_ingresos.csv

# %% [markdown]
# ETL Fija_accesos_tot.csv

# %% [markdown]
# Cargamos el data set Fija_accesos_tot.csv y realizamos una exploración para ver datos faltantes ,su estructura y visualizar las primeras líneas

# %%
# Cargamos el archivo 
archivo= r'C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/telefonia_fija/Fija_accesos_tot.csv'
print(f"Análisis para el archivo: {archivo}") 
df = pd.read_csv(archivo)

 # Realizamos el analisis  de el archivo
print(df.head())         
print(df.info())        
print(df.describe())     
print(f"Dimensiones del dataframe: {df.shape}")

# Análisamos el porsentaje de valores nulos valores nulos
print("Valores nulos por columna")
print(df.isnull().sum())

# Contamos el valores faltantes
missing_values = df.isnull().mean() * 100
print("Porcentaje de valores faltantes por columna:\n", missing_values)

# Contamos el número de filas duplicadas
num_duplicates = df.duplicated(keep=False).sum()
print("Número total de filas duplicadas:", num_duplicates)
print("\n" + "="*50 + "\n")  # Separador para cada archivo
# Out:
# Análisis para el archivo: C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/telefonia_fija/Fija_accesos_tot.csv
#     Año  Trimestre  Accesos telefonía fija (total)  \
# 0  2014          1                         9562231
# 1  2014          2                         9548994
# 2  2014          3                         9613361
# 3  2014          4                         9689752
# 4  2015          1                        10086221
#
#    Accesos telefonía fija (hogares)  Accesos telefonía fija (comercial)  \
# 0                           7897980                             1065834
# 1                           7872511                             1073038
# 2                           7924613                             1091747
# 3                           7989623                             1106502
# 4                           8358053                             1134427
#
#    Accesos telefonía fija (gobierno)  Accesos telefonía fija (otros)  \
# 0                              30917                          567500
# 1                              31339                          572106
# 2                              32516                          564485
# 3                              33139                          560488
# 4                              36888                          556853
#
#         Periodo
# 0   Ene-Mar 2014
# 1   Abr-Jun 2014
# 2  Jul-Sept 2014
# 3   Oct-Dic 2014
# 4   Ene-Mar 2015
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 8 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Año                                 42 non-null     int64
#  1   Trimestre                           42 non-null     int64
#  2   Accesos telefonía fija (total)      42 non-null     int64
#  3   Accesos telefonía fija (hogares)    42 non-null     int64
#  4   Accesos telefonía fija (comercial)  42 non-null     int64
#  5   Accesos telefonía fija (gobierno)   42 non-null     int64
#  6   Accesos telefonía fija (otros)      42 non-null     int64
#  7    Periodo                            42 non-null     object
# dtypes: int64(7), object(1)
# memory usage: 2.8+ KB
# None
#                Año  Trimestre  Accesos telefonía fija (total)  \
# count    42.000000  42.000000                    4.200000e+01
# mean   2018.761905   2.452381                    8.592559e+06
# std       3.074756   1.130560                    1.373150e+06
# min    2014.000000   1.000000                    6.908056e+06
# 25%    2016.000000   1.250000                    7.176322e+06
# 50%    2019.000000   2.000000                    8.228692e+06
# 75%    2021.000000   3.000000                    9.987342e+06
# max    2024.000000   4.000000                    1.037975e+07
#
#        Accesos telefonía fija (hogares)  Accesos telefonía fija (comercial)  \
# count                      4.200000e+01                        4.200000e+01
# mean                       7.512060e+06                        7.354724e+05
# std                        1.078206e+06                        1.824830e+05
# min                        6.161229e+06                        5.365000e+05
# 25%                        6.397089e+06                        6.124300e+05
# 50%                        7.269064e+06                        6.951375e+05
# 75%                        8.601376e+06                        7.245850e+05
# max                        9.037000e+06                        1.134427e+06
#
#        Accesos telefonía fija (gobierno)  Accesos telefonía fija (otros)
# count                          42.000000                       42.000000
# mean                        33591.547619                   311434.952381
# std                          4116.736235                   201079.663981
# min                         26497.000000                    89347.000000
# 25%                         31022.500000                   119939.750000
# 50%                         34296.500000                   277056.000000
# 75%                         37068.000000                   539018.000000
# max                         39825.000000                   572106.000000
# Dimensiones del dataframe: (42, 8)
# Valores nulos por columna
# Año                                   0
# Trimestre                             0
# Accesos telefonía fija (total)        0
# Accesos telefonía fija (hogares)      0
# Accesos telefonía fija (comercial)    0
# Accesos telefonía fija (gobierno)     0
# Accesos telefonía fija (otros)        0
#  Periodo                              0
# dtype: int64
# Porcentaje de valores faltantes por columna:
#  Año                                   0.0
# Trimestre                             0.0
# Accesos telefonía fija (total)        0.0
# Accesos telefonía fija (hogares)      0.0
# Accesos telefonía fija (comercial)    0.0
# Accesos telefonía fija (gobierno)     0.0
# Accesos telefonía fija (otros)        0.0
#  Periodo                              0.0
# dtype: float64
# Número total de filas duplicadas: 0
#
# ==================================================

# %% [markdown]
# Cambiamos el formato de fecha para que sea un formato más compatible con Python uniendo la columna fecha con la columna trimestre y borramos la columna Periodo

# %%
# Cargamos el archivo CSV
archivo = r'C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/telefonia_fija/Fija_accesos_tot.csv'
df = pd.read_csv(archivo)

# Mapeamos los trimestres al último día de cada trimestre
trimestre_map = {1: "03-31", 2: "06-30", 3: "09-30", 4: "12-31"}

# Convertimos 'Año' a cadena y mapear 'Trimestre' al último día del trimestre
if 'Año' in df.columns and 'Trimestre' in df.columns:
    df['Año'] = df['Año'].astype(str)
    df['Trimestre'] = df['Trimestre'].map(trimestre_map)

    # Creamos la columna 'Fecha' combinando 'Año' y 'Trimestre'
    df['Fecha'] = pd.to_datetime(df['Año'] + "-" + df['Trimestre'])

    # Borramos  las columnas 'Año' y 'Trimestre'
    df.drop(columns=['Año', 'Trimestre'], inplace=True)

        # Eliminamos la columna 'Periodo'
    df.columns = df.columns.str.strip()
    if 'Periodo' in df.columns:
        df.drop(columns=['Periodo'], inplace=True)

    # Reordenamos las columnas 
    cols = ['Fecha'] + [col for col in df.columns if col != 'Fecha']
    df = df[cols]
else:
    print("Error: Las columnas 'Año' y 'Trimestre' no se encontraron en los datos.")


    # Guardamos el DataFrame final en un archivo CSV
output_path = r'C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/telefonia_fija/Fija_accesos_tot.csv'
df.to_csv(output_path, index=False)

print(df.head())
# Out:
#        Fecha  Accesos telefonía fija (total)  \
# 0 2014-03-31                         9562231
# 1 2014-06-30                         9548994
# 2 2014-09-30                         9613361
# 3 2014-12-31                         9689752
# 4 2015-03-31                        10086221
#
#    Accesos telefonía fija (hogares)  Accesos telefonía fija (comercial)  \
# 0                           7897980                             1065834
# 1                           7872511                             1073038
# 2                           7924613                             1091747
# 3                           7989623                             1106502
# 4                           8358053                             1134427
#
#    Accesos telefonía fija (gobierno)  Accesos telefonía fija (otros)
# 0                              30917                          567500
# 1                              31339                          572106
# 2                              32516                          564485
# 3                              33139                          560488
# 4                              36888                          556853

# %% [markdown]
# ETL Fija_ingresos.csv

# %% [markdown]
# Cargamos el data set Fija_ingresos.csv y realizamos una exploración para ver datos faltantes ,su estructura y visualizar las primeras líneas

# %%
# Cargamos el archivo 
archivo= r'C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/telefonia_fija/Fija_ingresos.csv'
print(f"Análisis para el archivo: {archivo}")  
df = pd.read_csv(archivo)

 # Realizamos el analisis  de el archivo
print(df.head())         
print(df.info())        
print(df.describe())     
print(f"Dimensiones del dataframe: {df.shape}")

# Análisamos el porsentaje de valores nulos valores nulos
print("Valores nulos por columna")
print(df.isnull().sum())

# Contamos el valores faltantes
missing_values = df.isnull().mean() * 100
print("Porcentaje de valores faltantes por columna:\n", missing_values)

# Contamos el número de filas duplicadas
num_duplicates = df.duplicated(keep=False).sum()
print("Número total de filas duplicadas:", num_duplicates)
print("\n" + "="*50 + "\n")  # Separador para cada archivo
# Out:
# Análisis para el archivo: C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/telefonia_fija/Fija_ingresos.csv
#     Año  Trimestre  Ingresos (miles de $)
# 0  2014          1            2916071.754
# 1  2014          2            2974865.204
# 2  2014          3            3105462.022
# 3  2014          4            3339690.895
# 4  2015          1            3260124.752
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Año                    42 non-null     int64
#  1   Trimestre              42 non-null     int64
#  2   Ingresos (miles de $)  42 non-null     float64
# dtypes: float64(1), int64(2)
# memory usage: 1.1 KB
# None
#                Año  Trimestre  Ingresos (miles de $)
# count    42.000000  42.000000           4.200000e+01
# mean   2018.761905   2.452381           2.507723e+07
# std       3.074756   1.130560           3.701216e+07
# min    2014.000000   1.000000           2.916072e+06
# 25%    2016.000000   1.250000           4.955125e+06
# 50%    2019.000000   2.000000           1.282157e+07
# 75%    2021.000000   3.000000           2.781857e+07
# max    2024.000000   4.000000           1.924084e+08
# Dimensiones del dataframe: (42, 3)
# Valores nulos por columna
# Año                      0
# Trimestre                0
# Ingresos (miles de $)    0
# dtype: int64
# Porcentaje de valores faltantes por columna:
#  Año                      0.0
# Trimestre                0.0
# Ingresos (miles de $)    0.0
# dtype: float64
# Número total de filas duplicadas: 0
#
# ==================================================

# %% [markdown]
# Cambiamos el formato de fecha para que sea un formato más compatible con Python uniendo la columna fecha con la columna trimestre.

# %%
# Cargamos el archivo CSV
archivo = r'C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/telefonia_fija/Fija_ingresos.csv'
df = pd.read_csv(archivo)

# Mapeamos los trimestres al último día de cada trimestre
trimestre_map = {1: "03-31", 2: "06-30", 3: "09-30", 4: "12-31"}

# Convertimos 'Año' a cadena y mapear 'Trimestre' al último día del trimestre
if 'Año' in df.columns and 'Trimestre' in df.columns:
    df['Año'] = df['Año'].astype(str)
    df['Trimestre'] = df['Trimestre'].map(trimestre_map)

    # Creamos la columna 'Fecha' combinando 'Año' y 'Trimestre'
    df['Fecha'] = pd.to_datetime(df['Año'] + "-" + df['Trimestre'])

    # Borramos  las columnas 'Año' y 'Trimestre'
    df.drop(columns=['Año', 'Trimestre'], inplace=True)

    # Reordenamos las columnas 
    cols = ['Fecha'] + [col for col in df.columns if col != 'Fecha']
    df = df[cols]
else:
    print("Error: Las columnas 'Año' y 'Trimestre' no se encontraron en los datos.")

    # Guardamos el DataFrame final en un archivo CSV
output_path = r'C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/telefonia_fija/Fija_ingresos.csv'
df.to_csv(output_path, index=False)

print(df.head())
# Out:
#        Fecha  Ingresos (miles de $)
# 0 2014-03-31            2916071.754
# 1 2014-06-30            2974865.204
# 2 2014-09-30            3105462.022
# 3 2014-12-31            3339690.895
# 4 2015-03-31            3260124.752

# %% [markdown]
# ETL Fija_penetracion_prov.csv

# %% [markdown]
# Cargamos el data set Fija_penetracion_prov.csv y realizamos una exploración para ver datos faltantes ,su estructura y visualizar las primeras líneas

# %%
# Cargamos el archivo 
archivo= r'C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/telefonia_fija/Fija_penetracion_prov.csv'
print(f"Análisis para el archivo: {archivo}") 
df = pd.read_csv(archivo)

 # Realizamos el analisis  de el archivo
print(df.head())         
print(df.info())        
print(df.describe())     
print(f"Dimensiones del dataframe: {df.shape}")

# Análisamos el porsentaje de valores nulos valores nulos
print("Valores nulos por columna")
print(df.isnull().sum())

# Contamos el valores faltantes
missing_values = df.isnull().mean() * 100
print("Porcentaje de valores faltantes por columna:\n", missing_values)

# Contamos el número de filas duplicadas
num_duplicates = df.duplicated(keep=False).sum()
print("Número total de filas duplicadas:", num_duplicates)
print("\n" + "="*50 + "\n")  # Separador para cada archivo
# Out:
# Análisis para el archivo: C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/telefonia_fija/Fija_penetracion_prov.csv
#     Año  Trimestre        Provincia  Accesos telefonía fija por cada 100 hab  \
# 0  2014          1     Buenos Aires                                26.717541
# 1  2014          1  Capital Federal                                52.663108
# 2  2014          1        Catamarca                                10.034940
# 3  2014          1            Chaco                                 9.094093
# 4  2014          1           Chubut                                17.657914
#
#    Accesos telefonía fija por cada 100 hogares
# 0                                    85.264880
# 1                                   128.570341
# 2                                    39.446596
# 3                                    34.022053
# 4                                    57.594630
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1008 entries, 0 to 1007
# Data columns (total 5 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Año                                          1008 non-null   int64
#  1   Trimestre                                    1008 non-null   int64
#  2   Provincia                                    1008 non-null   object
#  3   Accesos telefonía fija por cada 100 hab      1008 non-null   float64
#  4   Accesos telefonía fija por cada 100 hogares  1008 non-null   float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 39.5+ KB
# None
#                Año    Trimestre  Accesos telefonía fija por cada 100 hab  \
# count  1008.000000  1008.000000                              1008.000000
# mean   2018.761905     2.452381                                13.608826
# std       3.039439     1.117574                                 9.236039
# min    2014.000000     1.000000                                 3.588433
# 25%    2016.000000     1.000000                                 7.665753
# 50%    2019.000000     2.000000                                10.679524
# 75%    2021.000000     3.000000                                17.377891
# max    2024.000000     4.000000                                57.859352
#
#        Accesos telefonía fija por cada 100 hogares
# count                                  1008.000000
# mean                                     45.230426
# std                                      22.239948
# min                                      14.032975
# 25%                                      29.258913
# 50%                                      38.649369
# 75%                                      56.580349
# max                                     138.277049
# Dimensiones del dataframe: (1008, 5)
# Valores nulos por columna
# Año                                            0
# Trimestre                                      0
# Provincia                                      0
# Accesos telefonía fija por cada 100 hab        0
# Accesos telefonía fija por cada 100 hogares    0
# dtype: int64
# Porcentaje de valores faltantes por columna:
#  Año                                            0.0
# Trimestre                                      0.0
# Provincia                                      0.0
# Accesos telefonía fija por cada 100 hab        0.0
# Accesos telefonía fija por cada 100 hogares    0.0
# dtype: float64
# Número total de filas duplicadas: 0
#
# ==================================================

# %% [markdown]
# Cambiamos el formato de fecha para que sea un formato más compatible con Python uniendo la columna fecha con la columna trimestre y se crea la columna Id_Provincia

# %%
# Cargamos el archivo CSV
archivo = r'C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/telefonia_fija/Fija_penetracion_prov.csv'
df = pd.read_csv(archivo)

# Mapeamos los trimestres al último día de cada trimestre
trimestre_map = {1: "03-31", 2: "06-30", 3: "09-30", 4: "12-31"}

# Convertimos 'Año' a cadena y mapear 'Trimestre' al último día del trimestre
if 'Año' in df.columns and 'Trimestre' in df.columns:
    df['Año'] = df['Año'].astype(str)
    df['Trimestre'] = df['Trimestre'].map(trimestre_map)

    # Creamos la columna 'Fecha' combinando 'Año' y 'Trimestre'
    df['Fecha'] = pd.to_datetime(df['Año'] + "-" + df['Trimestre'])

    # Borramos  las columnas 'Año' y 'Trimestre'
    df.drop(columns=['Año', 'Trimestre'], inplace=True)

    # Reordenamos las columnas 
    cols = ['Fecha'] + [col for col in df.columns if col != 'Fecha']
    df = df[cols]
else:
    print("Error: Las columnas 'Año' y 'Trimestre' no se encontraron en los datos.")


# Identificamos todas las provincias en el dataset
provincias = df['Provincia'].unique()
print("Provincias en Argentina:", provincias)
print("Número total de provincias:", len(provincias))

# Creamos un diccionario de ID únicos para cada provincia, comenzando desde 1
provincia_id_map = {provincia: idx + 1 for idx, provincia in enumerate(provincias)}

# Creamos la columna Id_Provincia usando el diccionario
df['Id_Provincia'] = df['Provincia'].map(provincia_id_map)

# Ordenamos el dataset según el orden de columnas
column_order = ['Id_Provincia','Provincia', 'Fecha','Accesos telefonía fija por cada 100 hab','Accesos telefonía fija por cada 100 hogares']
df = df[column_order]

# Guardamos el DataFrame final en un archivo CSV
output_path = r'C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/telefonia_fija/Fija_penetracion_prov.csv'
df.to_csv(output_path, index=False)

print(df.head())
# Out:
# Provincias en Argentina: ['Buenos Aires' 'Capital Federal' 'Catamarca' 'Chaco' 'Chubut' 'Córdoba'
#  'Corrientes' 'Entre Ríos' 'Formosa' 'Jujuy' 'La Pampa' 'La Rioja'
#  'Mendoza' 'Misiones' 'Neuquén' 'Río Negro' 'Salta' 'San Juan' 'San Luis'
#  'Santa Cruz' 'Santa Fe' 'Santiago del Estero' 'Tierra del Fuego'
#  'Tucumán']
# Número total de provincias: 24
#    Id_Provincia        Provincia      Fecha  \
# 0             1     Buenos Aires 2014-03-31
# 1             2  Capital Federal 2014-03-31
# 2             3        Catamarca 2014-03-31
# 3             4            Chaco 2014-03-31
# 4             5           Chubut 2014-03-31
#
#    Accesos telefonía fija por cada 100 hab  \
# 0                                26.717541
# 1                                52.663108
# 2                                10.034940
# 3                                 9.094093
# 4                                17.657914
#
#    Accesos telefonía fija por cada 100 hogares
# 0                                    85.264880
# 1                                   128.570341
# 2                                    39.446596
# 3                                    34.022053
# 4                                    57.594630

# %% [markdown]
# ETL Fija_penetracion_tot.csv

# %% [markdown]
# Cargamos el data set Fija_penetracion_tot.csv y realizamos una exploración para ver datos faltantes ,su estructura y visualizar las primeras líneas

# %%
# Cargamos el archivo 

df = pd.read_csv(r'H:/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/telefonia_fija/Fija_penetracion_tot.csv')

 # Realizamos el analisis  de el archivo
print(df.head())         
print(df.info())        
print(df.describe())     
print(f"Dimensiones del dataframe: {df.shape}")

# Análisamos el porsentaje de valores nulos valores nulos
print("Valores nulos por columna")
print(df.isnull().sum())

# Contamos el valores faltantes
missing_values = df.isnull().mean() * 100
print("Porcentaje de valores faltantes por columna:\n", missing_values)

# Contamos el número de filas duplicadas
num_duplicates = df.duplicated(keep=False).sum()
print("Número total de filas duplicadas:", num_duplicates)
print("\n" + "="*50 + "\n")  # Separador para cada archivo
# Out:
#     Año  Trimestre  Accesos telefonía fija por cada 100 hab  \
# 0  2024          2                                14.291425
# 1  2024          1                                14.719928
# 2  2023          4                                15.440544
# 3  2023          3                                15.694047
# 4  2023          2                                15.809957
#
#    Accesos telefonía fija por cada 100 hogares
# 0                                    45.442151
# 1                                    46.848116
# 2                                    49.696153
# 3                                    50.552590
# 4                                    50.965804
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 4 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Año                                          42 non-null     int64
#  1   Trimestre                                    42 non-null     int64
#  2   Accesos telefonía fija por cada 100 hab      42 non-null     float64
#  3   Accesos telefonía fija por cada 100 hogares  42 non-null     float64
# dtypes: float64(2), int64(2)
# memory usage: 1.4 KB
# None
#                Año  Trimestre  Accesos telefonía fija por cada 100 hab  \
# count    42.000000  42.000000                                42.000000
# mean   2018.761905   2.452381                                19.357188
# std       3.074756   1.130560                                 3.544160
# min    2014.000000   1.000000                                14.291425
# 25%    2016.000000   1.250000                                15.837317
# 50%    2019.000000   2.000000                                18.349007
# 75%    2021.000000   3.000000                                23.145359
# max    2024.000000   4.000000                                23.832910
#
#        Accesos telefonía fija por cada 100 hogares
# count                                    42.000000
# mean                                     62.810319
# std                                      11.921882
# min                                      45.442151
# 25%                                      51.064029
# 50%                                      59.354487
# 75%                                      75.440797
# max                                      77.653934
# Dimensiones del dataframe: (42, 4)
# Valores nulos por columna
# Año                                            0
# Trimestre                                      0
# Accesos telefonía fija por cada 100 hab        0
# Accesos telefonía fija por cada 100 hogares    0
# dtype: int64
# Porcentaje de valores faltantes por columna:
#  Año                                            0.0
# Trimestre                                      0.0
# Accesos telefonía fija por cada 100 hab        0.0
# Accesos telefonía fija por cada 100 hogares    0.0
# dtype: float64
# Número total de filas duplicadas: 0
#
# ==================================================

# %% [markdown]
# Cambiamos el formato de fecha para que sea un formato más compatible con Python uniendo la columna fecha con la columna trimestre.

# %%
# Cargamos el archivo CSV
archivo = r'H:/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/telefonia_fija/Fija_penetracion_tot.csv'
df = pd.read_csv(archivo)

# Mapeamos los trimestres al último día de cada trimestre
trimestre_map = {1: "03-31", 2: "06-30", 3: "09-30", 4: "12-31"}

# Convertimos 'Año' a cadena y mapear 'Trimestre' al último día del trimestre
if 'Año' in df.columns and 'Trimestre' in df.columns:
    df['Año'] = df['Año'].astype(str)
    df['Trimestre'] = df['Trimestre'].map(trimestre_map)

    # Creamos la columna 'Fecha' combinando 'Año' y 'Trimestre'
    df['Fecha'] = pd.to_datetime(df['Año'] + "-" + df['Trimestre'])

    # Borramos  las columnas 'Año' y 'Trimestre'
    df.drop(columns=['Año', 'Trimestre'], inplace=True)

    # Reordenamos las columnas 
    cols = ['Fecha'] + [col for col in df.columns if col != 'Fecha']
    df = df[cols]
else:
    print("Error: Las columnas 'Año' y 'Trimestre' no se encontraron en los datos.")

    
# Guardamos el DataFrame final en un archivo CSV
output_path = r'H:/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/telefonia_fija/Fija_penetracion_tot.csv'
df.to_csv(output_path, index=False)

print(df.head())
# Out:
#        Fecha  Accesos telefonía fija por cada 100 hab  \
# 0 2024-06-30                                14.291425
# 1 2024-03-31                                14.719928
# 2 2023-12-31                                15.440544
# 3 2023-09-30                                15.694047
# 4 2023-06-30                                15.809957
#
#    Accesos telefonía fija por cada 100 hogares
# 0                                    45.442151
# 1                                    46.848116
# 2                                    49.696153
# 3                                    50.552590
# 4                                    50.965804

# %% [markdown]
# ETL Fija_prov_tipo.csv

# %% [markdown]
# Cargamos el data set Fija_prov_tipo.csv y realizamos una exploración para ver datos faltantes ,su estructura y visualizar las primeras líneas

# %%
# Cargamos el archivo 
archivo= r'C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/telefonia_fija/Fija_prov_tipo.csv'
print(f"Análisis para el archivo: {archivo}")  
df = pd.read_csv(archivo)

 # Realizamos el analisis  de el archivo
print(df.head())         
print(df.info())        
print(df.describe())     
print(f"Dimensiones del dataframe: {df.shape}")

# Análisamos el porsentaje de valores nulos valores nulos
print("Valores nulos por columna")
print(df.isnull().sum())

# Contamos el valores faltantes
missing_values = df.isnull().mean() * 100
print("Porcentaje de valores faltantes por columna:\n", missing_values)

# Contamos el número de filas duplicadas
num_duplicates = df.duplicated(keep=False).sum()
print("Número total de filas duplicadas:", num_duplicates)
print("\n" + "="*50 + "\n")  # Separador para cada archivo
# Out:
# Análisis para el archivo: C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/telefonia_fija/Fija_prov_tipo.csv
#     Año  Trimestre        Provincia  Accesos telefonía fija (total)  \
# 0  2024          2     Buenos Aires                         3147886
# 1  2024          2  Capital Federal                         1651854
# 2  2024          2        Catamarca                           20365
# 3  2024          2            Chaco                           53967
# 4  2024          2           Chubut                           54140
#
#    Accesos telefonía fija (hogares)  Accesos telefonía fija (comercial)  \
# 0                           2793773                              299661
# 1                           1466033                              157247
# 2                             18074                                1939
# 3                             47897                                5137
# 4                             48049                                5154
#
#    Accesos telefonía fija (gobierno)  Accesos telefonía fija (otros)
# 0                              12436                           42016
# 1                               6526                           22048
# 2                                 80                             272
# 3                                213                             720
# 4                                214                             723
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1008 entries, 0 to 1007
# Data columns (total 8 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Año                                 1008 non-null   int64
#  1   Trimestre                           1008 non-null   int64
#  2   Provincia                           1008 non-null   object
#  3   Accesos telefonía fija (total)      1008 non-null   int64
#  4   Accesos telefonía fija (hogares)    1008 non-null   int64
#  5   Accesos telefonía fija (comercial)  1008 non-null   int64
#  6   Accesos telefonía fija (gobierno)   1008 non-null   int64
#  7   Accesos telefonía fija (otros)      1008 non-null   int64
# dtypes: int64(7), object(1)
# memory usage: 63.1+ KB
# None
#                Año    Trimestre  Accesos telefonía fija (total)  \
# count  1008.000000  1008.000000                    1.008000e+03
# mean   2018.761905     2.452381                    3.567824e+05
# std       3.039439     1.117574                    8.245072e+05
# min    2014.000000     1.000000                    1.475200e+04
# 25%    2016.000000     1.000000                    5.061250e+04
# 50%    2019.000000     2.000000                    8.635550e+04
# 75%    2021.000000     3.000000                    1.877165e+05
# max    2024.000000     4.000000                    4.916108e+06
#
#        Accesos telefonía fija (hogares)  Accesos telefonía fija (comercial)  \
# count                      1.008000e+03                         1008.000000
# mean                       3.121301e+05                        30468.440476
# std                        7.188757e+05                        71893.667408
# min                        1.309300e+04                         1252.000000
# 25%                        4.310450e+04                         4266.250000
# 50%                        7.684550e+04                         7175.500000
# 75%                        1.674970e+05                        15132.750000
# max                        4.280149e+06                       540095.000000
#
#        Accesos telefonía fija (gobierno)  Accesos telefonía fija (otros)
# count                        1008.000000                     1008.000000
# mean                         1396.330357                    12787.511905
# std                          3197.632976                    36036.816126
# min                            57.000000                      197.000000
# 25%                           189.250000                     1159.000000
# 50%                           359.000000                     2611.500000
# 75%                           757.500000                     6603.000000
# max                         18514.000000                   265115.000000
# Dimensiones del dataframe: (1008, 8)
# Valores nulos por columna
# Año                                   0
# Trimestre                             0
# Provincia                             0
# Accesos telefonía fija (total)        0
# Accesos telefonía fija (hogares)      0
# Accesos telefonía fija (comercial)    0
# Accesos telefonía fija (gobierno)     0
# Accesos telefonía fija (otros)        0
# dtype: int64
# Porcentaje de valores faltantes por columna:
#  Año                                   0.0
# Trimestre                             0.0
# Provincia                             0.0
# Accesos telefonía fija (total)        0.0
# Accesos telefonía fija (hogares)      0.0
# Accesos telefonía fija (comercial)    0.0
# Accesos telefonía fija (gobierno)     0.0
# Accesos telefonía fija (otros)        0.0
# dtype: float64
# Número total de filas duplicadas: 0
#
# ==================================================

# %%
# Cargamos el archivo CSV
archivo = r'C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/telefonia_fija/Fija_prov_tipo.csv'
df = pd.read_csv(archivo)

# Mapeamos los trimestres al último día de cada trimestre
trimestre_map = {1: "03-31", 2: "06-30", 3: "09-30", 4: "12-31"}

# Convertimos 'Año' a cadena y mapear 'Trimestre' al último día del trimestre
if 'Año' in df.columns and 'Trimestre' in df.columns:
    df['Año'] = df['Año'].astype(str)
    df['Trimestre'] = df['Trimestre'].map(trimestre_map)

    # Creamos la columna 'Fecha' combinando 'Año' y 'Trimestre'
    df['Fecha'] = pd.to_datetime(df['Año'] + "-" + df['Trimestre'])

    # Borramos  las columnas 'Año' y 'Trimestre'
    df.drop(columns=['Año', 'Trimestre'], inplace=True)

    # Reordenamos las columnas 
    cols = ['Fecha'] + [col for col in df.columns if col != 'Fecha']
    df = df[cols]
else:
    print("Error: Las columnas 'Año' y 'Trimestre' no se encontraron en los datos.")


# Identificamos todas las provincias en el dataset
provincias = df['Provincia'].unique()
print("Provincias en Argentina:", provincias)
print("Número total de provincias:", len(provincias))

# Creamos un diccionario de ID únicos para cada provincia, comenzando desde 1
provincia_id_map = {provincia: idx + 1 for idx, provincia in enumerate(provincias)}

# Creamos la columna Id_Provincia usando el diccionario
df['Id_Provincia'] = df['Provincia'].map(provincia_id_map)

# Eliminamos columna Periodo
df.columns = df.columns.str.strip()
if 'Periodo' in df.columns:
     df.drop(columns=['Periodo'], inplace=True)

# Guardamos el DataFrame final en un archivo CSV
output_path = r'C:/Users/jrgsi/OneDrive/Escritorio/PROUECTOS HENRY/PROYECTO INDIVIDUAL DOS/datos/dataset .csv/telefonia_fija/Fija_prov_tipo.csv'
df.to_csv(output_path, index=False)

print(df.head())
# Out:
# Provincias en Argentina: ['Buenos Aires' 'Capital Federal' 'Catamarca' 'Chaco' 'Chubut' 'Córdoba'
#  'Corrientes' 'Entre Ríos' 'Formosa' 'Jujuy' 'La Pampa' 'La Rioja'
#  'Mendoza' 'Misiones' 'Neuquén' 'Río Negro' 'Salta' 'San Juan' 'San Luis'
#  'Santa Cruz' 'Santa Fe' 'Santiago del Estero' 'Tierra del Fuego'
#  'Tucumán']
# Número total de provincias: 24
#        Fecha        Provincia  Accesos telefonía fija (total)  \
# 0 2024-06-30     Buenos Aires                         3147886
# 1 2024-06-30  Capital Federal                         1651854
# 2 2024-06-30        Catamarca                           20365
# 3 2024-06-30            Chaco                           53967
# 4 2024-06-30           Chubut                           54140
#
#    Accesos telefonía fija (hogares)  Accesos telefonía fija (comercial)  \
# 0                           2793773                              299661
# 1                           1466033                              157247
# 2                             18074                                1939
# 3                             47897                                5137
# 4                             48049                                5154
#
#    Accesos telefonía fija (gobierno)  Accesos telefonía fija (otros)  \
# 0                              12436                           42016
# 1                               6526                           22048
# 2                                 80                             272
# 3                                213                             720
# 4                                214                             723
#
#    Id_Provincia
# 0             1
# 1             2
# 2             3
# 3             4
# 4             5
